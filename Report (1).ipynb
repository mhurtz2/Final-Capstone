# %% [markdown]
# <h1>Capstone Report- Battle of the Neighborhoods</h1>

# %% [markdown]
# <h2>Introduction</h2>

# %% [markdown]
# The purpose of this project is to help people explore the venues in Scarborough, Toranto. It will allow for educated decisions on choosing the best neighborhoods.
#
# Like all people in a new place, those who have just moved to Scarbourough may have difficulty navigating and exploring, making finding places to connect difficult. This includes shops, restaurants, grocery stores, etc.
#
# Additionally, this project will look at housing prices, providing more information on deciding where to move.

# %% [markdown]
# <h2> Data</h2>

# %% [markdown]
# For simplicity's sake, we will use the Toronto Postal Code dataset from the Wikipedia page in week 3. This dataset will be scraped for latitude, longitude, and zipcodes (https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M).
#
# We will also use Foursquare API, which will provide data on different venues in the area. Foursquare is a location provider with various types of area-specific data, such as neighborhood and venue latitude and longitude.

# %% [markdown]
# <h2>Methodology</h2>

# %% [markdown]
# **Clustering:**
# To compare the similarities of two cities, we decided to explore neighborhoods, segment them, and group them into clusters to find similar neighborhoods in other cities. To be able to do that, we need to cluster data using the k-means clustering algorithm.

# %% [markdown]
# <h2>Results</h2>

# %% [markdown]
# **Venue Locations**

# %% [markdown]
# ![2020-08-19%20%282%29.png](attachment:2020-08-19%20%282%29.png)

# %% [markdown]
# **Cluster Map**

# %% [markdown]
# ![2020-08-19%20%286%29.png](attachment:2020-08-19%20%286%29.png)

# %% [markdown]
# **Average Housing Prices:**

# %% [markdown]
# ![housing%20prices.png](attachment:housing%20prices.png)

# %% [markdown]
# <h2>Discussion</h2>

# %% [markdown]
# The purpose of this project is to search for better neighborhoods using different algorithms and data cleaning techniques. This would make moving far easier, as it would allow them to make informed decisions based on their personal preferences. Analyzing house prices in the area also greatly helps when making such decisions.

# %% [markdown]
# <h2>Conclusion</h2>

# %% [markdown]
# In this project, I used k-means clustering to separated the neighborhood into different clusters, analyzing location, venues, and housing prices.
#
# I have never attempted a project like this before, and feel very rewarded with the efforts. This project has shown how to apply data scraping in a real project. I also learned that mapping with Folium is a very useful for consolidating information.
#
#
# **Future Project:**
# I hope to use similar techniques to start a new project analysis COVID cases, deaths, and hospitalizations in different counties in my home state of Nebraska.
